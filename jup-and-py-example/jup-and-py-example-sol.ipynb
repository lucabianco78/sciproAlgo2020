# %%
#Please execute this cell
import sys
sys.path.append('../')
import jupman
jupman.init()

#NOTE: init() injects js and css stuff, which might not be necessary for exercises 
#      and sometimes even undesirable
#      Please read https://jupman.readthedocs.io/en/latest/usage.html#Running-Jupyter
# Out:
# <style>
#
# /** ONLY AVAILABLE IN JUPYTER **/
#
# #jupman-nav {
#     position: fixed;
#     top: 10px;
#     left: 5px;
#     background: white;
#     width: 200px;
#     padding: 10px;
#     z-index: 10;
# }
#
# /* style="background: rgba(255, 255, 255, 0);" class="unstyled" */
#
# #jupman-toc {
#     position: fixed;
#     top: 100px;
#     left: -55px;
#     background: rgba(255, 255, 255, 0);
#
#     height: 80%;
#     width: 200px;
#     padding: 20px;
#     z-index: 10;
#     overflow-y: scroll;
#         /* font-size: 50%; */
# }
#
#
#
# code {
#     background-color:rgb(245, 249, 249) !important;
# }
#
#
# .jupman-nav-item {
#     font-weight:bold;
#     font-size:120%
# }
#
# .jupman-chapter-link {
#     font-size:150%;
#     margin-right:15px;
# }
#
# .jupman-chapter-link a {
#     text-decoration: none;
# }
#
# .jupman-title {
#     font-size:250%;
#     font-weight:bold
# }
#
# .jupman-warn {
#     background-color: #fcf2f2;
#     border-left: 5px solid #dfb5b4;
# ...

# %% [markdown]
# # Jupyter and python example
#
# Most complex example of a notebook with exercises both in Jupyter and Python files.

# %% [markdown]
# ## [Download exercises zip](../_static/generated/jup-and-py-example.zip)
#
# [Browse files online](https://github.com/DavidLeoni/jupman/tree/master/jup-and-py-example)
#
# ## What to do
#
# - unzip exercises in a folder, you should get something like this:
#
# ```
# jup-and-py-example
#    jup-and-py-example.ipynb
#    jup-and-py-example_sol.ipynb
#    lab.py
#    lab_test.py
#    lab_sol.py
# ```
#
#
# - open the editor of your choice (for example Visual Studio Code, Spyder or PyCharme), and edit `lab.py` file
# - Go on reading this notebook, and follow instuctions inside.

# %% [markdown]
# ### Let's begin
#
# You are going to program a simulator of bouncing clowns. To do so, we are going to load this module:

# %%
import local

# %%
local.gimme(5)
# Out:
# It was a 5 indeed

# %% [markdown]
# **Download test data**
#
# Local file:
#
# * [example.txt](example.txt)
# * [example.csv](example.csv)

# %% [markdown]
# ## Global image
# ![cc-by-5754](../_static/img/cc-by.png)

# %% [markdown]
# ## Local exercise image
#
# ![leaves-98231](img/leaves.png)

# %% [markdown]
# ## Python tutor

# %%
x = 5
y = 6
z = x + y

jupman.pytut()
# Out:
#         <script src="../_static/js/pytutor-embed.bundle.min.js" type="application/javascript"></script>
#
#         <script id="json-jmd9c8aa4e-93fe-4823-824f-c48d31713d8f" type="application/json" >
#             {"code": " \nx = 5\ny = 6\nz = x + y", "trace": [{"func_name": "<module>", "line": 2, "stack_to_render": [], "globals": {}, "heap": {}, "event": "step_line", "stdout": "", "ordered_globals": []}, {"func_name": "<module>", "line": 3, "stack_to_render": [], "globals": {"x": 5}, "heap": {}, "event": "step_line", "stdout": "", "ordered_globals": ["x"]}, {"func_name": "<module>", "line": 4, "stack_to_render": [], "globals": {"x": 5, "y": 6}, "heap": {}, "event": "step_line", "stdout": "", "ordered_globals": ["x", "y"]}, {"func_name": "<module>", "line": 4, "stack_to_render": [], "globals": {"x": 5, "y": 6, "z": 11}, "heap": {}, "event": "return", "stdout": "", "ordered_globals": ["x", "y", "z"]}]}
#         </script>
# ...

# %% [markdown]
# ## Exercise in Jupyter
#
# Implement this function:

# %%
def hello(s):
    #jupman-raise
    print(s)
    #/jupman-raise
    
hello("Guybrush")
# Out:
# Guybrush

# %% [markdown]
# ## Exercise in Jupyter with Python Tutor
#
# Write some code to display a jungle of pies

# %%
import math

# write here

la = [math.pi] * 5

lb = [la] * 3

lc = [lb] * 4
print(la)

jupman.pytut()
# Out:
# [3.141592653589793, 3.141592653589793, 3.141592653589793, 3.141592653589793, 3.141592653589793]
#         <script src="../_static/js/pytutor-embed.bundle.min.js" type="application/javascript"></script>
#
#         <script id="json-jm7065ffae-15bc-421d-95a9-8b0abadfa8d7" type="application/json" >
# ...

# %% [markdown]
# ## Question in Jupyter
#
# **QUESTION**: Why learn coding?

# %% [markdown]
# **ANSWER**: So they pay me more
#
# ```python
# x + 1
# ```
#
# Some other comment
#
#     Some nasty formatting
#
# > even more formatting

# %% [markdown]
# ## Exercise in Python
#
# Start editing `lab.py` in text editor

# %%
from lab_sol import *

# %% [markdown]
# ## add
#
# Implement `add` function:

# %%
add(3,5)
# Out:
# 8

# %% [markdown]
# ## sub
#
# Implement sub function

# %%
sub(7,4)
# Out:
# 3

# %%
import lab_test
jupman.run(lab_test.MyTest)
# Out:
# ..
# ----------------------------------------------------------------------
# Ran 2 tests in 0.004s
#
# OK
